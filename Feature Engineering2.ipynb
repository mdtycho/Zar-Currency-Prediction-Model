# %%
import pandas as pd
import numpy as np
from ta import *

# %%
pd.set_option("display.max_rows",101)
pd.set_option("display.max_columns",44)

# %%
zar_history = pd.read_csv('zar_history.csv')

# %%
zar_history.head()
# Out:
#         Date     Open     High      Low    Close
# 0  6/19/2018  13.6441  13.9153  13.6293  13.8876
# 1  6/18/2018  13.4319  13.7294  13.3941  13.6441
# 2  6/15/2018  13.4548  13.4967  13.3616  13.4307
# 3  6/14/2018  13.3082  13.4704  13.1012  13.4548
# 4  6/13/2018  13.3325  13.4402  13.1945  13.3081

# %%
zar_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5016 entries, 0 to 5015
# Data columns (total 5 columns):
# Date     5016 non-null object
# Open     5016 non-null float64
# High     5016 non-null float64
# Low      5016 non-null float64
# Close    5016 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 196.0+ KB

# %%
zar_history['RSI'] = momentum.rsi(zar_history['Close'], fillna = True)

# %%
zar_history.head()
# Out:
#         Date     Open     High      Low    Close        RSI
# 0  6/19/2018  13.6441  13.9153  13.6293  13.8876  50.000000
# 1  6/18/2018  13.4319  13.7294  13.3941  13.6441   0.000000
# 2  6/15/2018  13.4548  13.4967  13.3616  13.4307   0.000000
# 3  6/14/2018  13.3082  13.4704  13.1012  13.4548   5.535281
# 4  6/13/2018  13.3325  13.4402  13.1945  13.3081   4.067047

# %% [markdown]
# <h2>Momentum Indicators</h2>

# %%
zar_history['TSI'] = momentum.tsi(zar_history['Close'], fillna = True)

# %% [markdown]
# ## Volatility Indicators

# %%
zar_history['ATR'] = volatility.average_true_range(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['BBH'] = volatility.bollinger_hband(zar_history['Close'], fillna = True)

# %%
zar_history['BHBI'] = volatility.bollinger_hband_indicator(zar_history['Close'], fillna = True)

# %%
zar_history['BBL'] = volatility.bollinger_lband(zar_history['Close'], fillna = True)

# %%
zar_history['BLBI'] = volatility.bollinger_lband_indicator(zar_history['Close'], fillna = True)

# %%
zar_history['BBMAVG'] = volatility.bollinger_mavg(zar_history['Close'], fillna = True)

# %%
zar_history['DCH'] = volatility.donchian_channel_hband(zar_history['Close'], fillna = True)

# %%
zar_history['DCHI'] = volatility.donchian_channel_hband_indicator(zar_history['Close'], fillna = True)

# %%
zar_history['DCL'] = volatility.donchian_channel_lband(zar_history['Close'], fillna = True)

# %%
zar_history['DCLI'] = volatility.donchian_channel_lband_indicator(zar_history['Close'], fillna = True)

# %%
zar_history['KCC'] = volatility.keltner_channel_central(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['KCH'] = volatility.keltner_channel_hband(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['KCHI'] = volatility.keltner_channel_hband_indicator(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['KCL'] = volatility.keltner_channel_lband(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['KCLI'] = volatility.keltner_channel_lband_indicator(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %% [markdown]
# ## Trend Indicators

# %%
zar_history['ADX'] = trend.adx(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['ADXI'] = trend.adx_indicator(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['ADXN'] = trend.adx_neg(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['ADXP'] = trend.adx_pos(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['CCI'] = trend.cci(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['DPO'] = trend.dpo(zar_history['Close'], fillna = True)

# %%
zar_history['SEMA'] = trend.ema_fast(zar_history['Close'], fillna = True)

# %%
zar_history['LEMA'] = trend.ema_slow(zar_history['Close'], fillna = True)

# %%
zar_history['Ichimoku'] = trend.ichimoku_a(zar_history['High'], zar_history['Low'], fillna = True)

# %%
zar_history['Ichimoku_b'] = trend.ichimoku_b(zar_history['High'], zar_history['Low'], fillna = True)

# %%
zar_history['KST'] = trend.kst(zar_history['Close'], fillna = True)

# %%
zar_history['KST_SIG'] = trend.kst_sig(zar_history['Close'], fillna = True)

# %%
zar_history['MACD'] = trend.macd(zar_history['Close'], fillna = True)

# %%
zar_history['MACD_DIFF'] = trend.macd_diff(zar_history['Close'], fillna = True)

# %%
zar_history['MACD_SIG'] = trend.macd_signal(zar_history['Close'], fillna = True)

# %%
zar_history['MI'] = trend.mass_index(zar_history['High'],zar_history['Low'], fillna = True)

# %%
zar_history['TRIX'] = trend.trix(zar_history['Close'], fillna = True)

# %%
zar_history['VIN'] = trend.vortex_indicator_neg(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %%
zar_history['VIP'] = trend.vortex_indicator_pos(zar_history['High'],zar_history['Low'],zar_history['Close'], fillna = True)

# %% [markdown]
# ## Other Indicators

# %%
zar_history['CR'] = others.cumulative_return(zar_history['Close'], fillna = True)

# %%
zar_history['DR'] = others.daily_return(zar_history['Close'], fillna = True)

# %% [markdown]
# ## A few simple checks to see if features created succesfully

# %%
zar_history.shape
# Out:
# (5016, 44)

# %%
zar_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5016 entries, 0 to 5015
# Data columns (total 44 columns):
# Date          5016 non-null object
# Open          5016 non-null float64
# High          5016 non-null float64
# Low           5016 non-null float64
# Close         5016 non-null float64
# RSI           5016 non-null float64
# TSI           5016 non-null float64
# ATR           5016 non-null float64
# BB            5016 non-null float64
# BHBI          5016 non-null float64
# BBL           5016 non-null float64
# BBH           5016 non-null float64
# BLBI          5016 non-null float64
# BBMAVG        5016 non-null float64
# DCH           5016 non-null float64
# DCHI          5016 non-null float64
# DCL           5016 non-null float64
# DCLI          5016 non-null float64
# KCC           5016 non-null float64
# KCH           5016 non-null float64
# KCHI          5016 non-null float64
# KCL           5016 non-null float64
# KCLI          5016 non-null float64
# ...

# %%
zar_history.head(100)
# Out:
#          Date     Open     High      Low    Close        RSI         TSI  \
# 0   6/19/2018  13.6441  13.9153  13.6293  13.8876  50.000000    0.000000
# 1   6/18/2018  13.4319  13.7294  13.3941  13.6441   0.000000 -100.000000
# 2   6/15/2018  13.4548  13.4967  13.3616  13.4307   0.000000 -100.000000
# 3   6/14/2018  13.3082  13.4704  13.1012  13.4548   5.535281  -97.116913
# 4   6/13/2018  13.3325  13.4402  13.1945  13.3081   4.067047  -95.987740
# 5   6/12/2018  13.1633  13.3473  13.1389  13.3325   8.397048  -94.026677
# 6   6/11/2018  13.0833  13.1756  12.9944  13.1633   6.288291  -93.032013
# 7    6/8/2018  12.9729  13.2863  12.9439  13.0677   5.458458  -92.497108
# 8    6/7/2018  12.7101  13.0488  12.6817  12.9759   4.805951  -92.226989
# 9    6/6/2018  12.7694  12.8764  12.6684  12.7101   3.505834  -92.291126
# 10   6/5/2018  12.5669  12.8310  12.5285  12.7696   9.385160  -91.107422
# 11   6/4/2018  12.6782  12.6841  12.5177  12.5672   7.679745  -90.397715
# ...

# %%
zar_
